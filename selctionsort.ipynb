# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin8254/algorithm/blob/master/selctionsort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Selection sort (選擇排序)

# %%
def Selction_Sort(datas):
    for i in range(len(datas)-1):
        min = i # 第一次選從第一個數開始,第二次從第二個數開始
        for j in range(i+1, len(datas)):    # 用記錄的max數與其他的比較
            if datas[j] < datas[min]:
                min = j

        datas[i], datas[min] = datas[min], datas[i]

        print(datas)
        print('---'*20)
    return datas


if __name__ == '__main__':
    import random
    a = list(range(16))
    random.shuffle(a)
    print(a)
    a = Selction_Sort(a)
    print(a)
# Out:
# [12, 13, 8, 11, 2, 7, 10, 14, 5, 4, 3, 9, 1, 15, 6, 0]
# [0, 13, 8, 11, 2, 7, 10, 14, 5, 4, 3, 9, 1, 15, 6, 12]
# ------------------------------------------------------------
# [0, 1, 8, 11, 2, 7, 10, 14, 5, 4, 3, 9, 13, 15, 6, 12]
# ------------------------------------------------------------
# [0, 1, 2, 11, 8, 7, 10, 14, 5, 4, 3, 9, 13, 15, 6, 12]
# ------------------------------------------------------------
# [0, 1, 2, 3, 8, 7, 10, 14, 5, 4, 11, 9, 13, 15, 6, 12]
# ------------------------------------------------------------
# [0, 1, 2, 3, 4, 7, 10, 14, 5, 8, 11, 9, 13, 15, 6, 12]
# ------------------------------------------------------------
# [0, 1, 2, 3, 4, 5, 10, 14, 7, 8, 11, 9, 13, 15, 6, 12]
# ------------------------------------------------------------
# [0, 1, 2, 3, 4, 5, 6, 14, 7, 8, 11, 9, 13, 15, 10, 12]
# ------------------------------------------------------------
# [0, 1, 2, 3, 4, 5, 6, 7, 14, 8, 11, 9, 13, 15, 10, 12]
# ...

# %% [markdown]
# 請加入註解
